# %%
import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords

import unicodedata

import re

from acquire import get_news_articles, get_blog_articles

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ihcrane/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /Users/ihcrane/nltk_data...
# True

# %%
stopwords_english = stopwords.words('english')

# %%
def clean_data(string):
    
    string = string.lower()
    
    string = unicodedata.normalize('NFKD', string).encode('ascii', 'ignore').decode('utf-8')
    
    string = re.sub(r'[^a-z0-9\s]', '', string)
    
    return string

# %%
def tokenize(string):
    
    tokenize = nltk.tokenize.ToktokTokenizer()
    
    tokens = tokenize.tokenize(string)
    
    return tokens

# %%
def stem(tokens):
    
    ps = nltk.porter.PorterStemmer()
    
    ps.stem('calling'), ps.stem('calls'), ps.stem('called'), ps.stem('call')
    ps.stem('house'), ps.stem('housing')
    
    stems = [ps.stem(word) for word in tokens]
    
    return ' '.join(stems)

# %%
def lemmatize(tokens):
    
    wnl = nltk.stem.WordNetLemmatizer()
    
    wnl.lemmatize('calling'), wnl.lemmatize('calls'), wnl.lemmatize('called'), wnl.lemmatize('call')
    wnl.lemmatize('house'), wnl.lemmatize('housing')
    wnl.lemmatize('mouse'), wnl.lemmatize('mice')
    
    lemmas = [wnl.lemmatize(word) for word in tokens]
    
    return ' '.join(lemmas)

# %%
def remove_stopwords(string, extra_words=[], exclude_words=[]):
    
    stopwords_english = stopwords.words('english')
    
    stopwords_english.extend(extra_words)
    stopwords_english = [word for word in stopwords_english if word not in exclude_words]
    
    string_with_stopwords_removed = [word for word in string if word not in stopwords_english]
    
    return ' '.join(string_with_stopwords_removed)

# %%
topics = ['sports','business','technology','entertainment']c

news_df = pd.DataFrame(get_news_articles(topics))
news_df
# Out:
#          category                                              title  \
# 0          sports  India's Ravichandran Ashwin becomes world numb...
# 1          sports  You are a harsh man: Hayden to Gavaskar over r...
# 2          sports  I just didn't agree with a lot of his opinions...
# 3          sports  Virat Kohli's reaction to Umesh Yadav equallin...
# 4          sports  Family of Kobe Bryant awarded around ₹240 cror...
# ..            ...                                                ...
# 95  entertainment  Diagnosed with Influenza B, staying away from ...
# 96  entertainment  Actors today focus on gym and social media mor...
# 97  entertainment  I relived my battle: Sagarika on Rani's 'Mrs C...
# 98  entertainment  Not solo anymore: Sidharth as paparazzi ask hi...
# 99  entertainment  Nandita said she won't make Zwigato with a sta...
#
#                                               content
# 0   Team India all-rounder Ravichandran Ashwin has...
# 1   Former Australia opener Matthew Hayden called ...
# 2   Ex-Australia batter Mark Waugh, who commentate...
# 3   A video has gone viral on social media showing...
# 4   Los Angeles County will pay Kobe Bryant's fami...
# ..                                                ...
# 95  Actress Debina Bonnerjee took to Instagram Sto...
# 96  Actor Govind Namdev has said that the current ...
# 97  Sagarika Chatterjee, whose life inspired Rani ...
# 98  Sidharth Malhotra was recently asked to pose s...
# 99  Comedian-actor Kapil Sharma said that when Nan...
#
# [100 rows x 3 columns]

# %%
url = 'https://codeup.com/blog/'

codeup_df = pd.DataFrame(get_blog_articles(url))
codeup_df
# Out:
#                                                title date_published  \
# 0  Black Excellence in Tech: Panelist Spotlight -...   Feb 16, 2023
# 1  Black excellence in tech: Panelist Spotlight -...   Feb 13, 2023
# 2  Black excellence in tech: Panelist Spotlight -...   Feb 10, 2023
# 3  Black excellence in tech: Panelist Spotlight -...    Feb 6, 2023
# 4  Coding Bootcamp or Self-Learning? Which is Bes...   Jan 20, 2023
# 5  Codeup Among Top 58 Best Coding Bootcamps of 2...   Jan 12, 2023
#
#                                              content
# 0   Codeup is hosting a Black Excellence in Tech ...
# 1  Codeup is hosting our second Black Excellence ...
# 2  Codeup is hosting our second Black Excellence ...
# 3  Codeup is hosting our second Black Excellence ...
# 4  If you’re interested in embarking on a career ...
# 5  Codeup was highlighted for being an establishe...

# %%
cleaned_content = []
stemmed = []
lemmatized = []

for content in news_df['content']:
    
    
    cleaned = clean_data(content)
    cleaned_content.append(cleaned)
    
    tokens = tokenize(cleaned)
    
    stemmed.append(stem(tokens))
    lemmatized.append(lemmatize(tokens))

# %%
news_df['clean'] = cleaned_content
news_df['stemmed'] = stemmed
news_df['lemmatized'] = lemmatized

# %%
news_df
# Out:
#          category                                              title  \
# 0          sports  India's Ravichandran Ashwin becomes world numb...
# 1          sports  You are a harsh man: Hayden to Gavaskar over r...
# 2          sports  I just didn't agree with a lot of his opinions...
# 3          sports  Virat Kohli's reaction to Umesh Yadav equallin...
# 4          sports  Family of Kobe Bryant awarded around ₹240 cror...
# ..            ...                                                ...
# 95  entertainment  Diagnosed with Influenza B, staying away from ...
# 96  entertainment  Actors today focus on gym and social media mor...
# 97  entertainment  I relived my battle: Sagarika on Rani's 'Mrs C...
# 98  entertainment  Not solo anymore: Sidharth as paparazzi ask hi...
# 99  entertainment  Nandita said she won't make Zwigato with a sta...
#
#                                               content  \
# 0   Team India all-rounder Ravichandran Ashwin has...
# 1   Former Australia opener Matthew Hayden called ...
# 2   Ex-Australia batter Mark Waugh, who commentate...
# 3   A video has gone viral on social media showing...
# 4   Los Angeles County will pay Kobe Bryant's fami...
# ..                                                ...
# 95  Actress Debina Bonnerjee took to Instagram Sto...
# 96  Actor Govind Namdev has said that the current ...
# 97  Sagarika Chatterjee, whose life inspired Rani ...
# 98  Sidharth Malhotra was recently asked to pose s...
# 99  Comedian-actor Kapil Sharma said that when Nan...
#
#                                                 clean  \
# 0   team india allrounder ravichandran ashwin has ...
# 1   former australia opener matthew hayden called ...
# 2   exaustralia batter mark waugh who commentated ...
# 3   a video has gone viral on social media showing...
# 4   los angeles county will pay kobe bryants famil...
# ..                                                ...
# 95  actress debina bonnerjee took to instagram sto...
# 96  actor govind namdev has said that the current ...
# 97  sagarika chatterjee whose life inspired rani m...
# 98  sidharth malhotra was recently asked to pose s...
# 99  comedianactor kapil sharma said that when nand...
#
#                                               stemmed  \
# 0   team india allround ravichandran ashwin ha bec...
# 1   former australia open matthew hayden call suni...
# 2   exaustralia batter mark waugh who comment in f...
# 3   a video ha gone viral on social media show vir...
# 4   lo angel counti will pay kobe bryant famili ne...
# ..                                                ...
# 95  actress debina bonnerje took to instagram stor...
# 96  actor govind namdev ha said that the current a...
# 97  sagarika chatterje whose life inspir rani muke...
# 98  sidharth malhotra wa recent ask to pose solo f...
# 99  comedianactor kapil sharma said that when nand...
#
#                                            lemmatized
# 0   team india allrounder ravichandran ashwin ha b...
# 1   former australia opener matthew hayden called ...
# 2   exaustralia batter mark waugh who commentated ...
# 3   a video ha gone viral on social medium showing...
# 4   los angeles county will pay kobe bryants famil...
# ..                                                ...
# 95  actress debina bonnerjee took to instagram sto...
# 96  actor govind namdev ha said that the current a...
# 97  sagarika chatterjee whose life inspired rani m...
# 98  sidharth malhotra wa recently asked to pose so...
# 99  comedianactor kapil sharma said that when nand...
#
# [100 rows x 6 columns]

# %%
cleaned_content = []
stemmed = []
lemmatized = []

for content in codeup_df['content']:
    
    
    cleaned = clean_data(content)
    cleaned_content.append(cleaned)
    
    tokens = tokenize(cleaned)
    
    stemmed.append(stem(tokens))
    lemmatized.append(lemmatize(tokens))

# %%
codeup_df['clean'] = cleaned_content
codeup_df['stemmed'] = stemmed
codeup_df['lemmatized'] = lemmatized

# %%
codeup_df
# Out:
#                                                title date_published  \
# 0  Black Excellence in Tech: Panelist Spotlight -...   Feb 16, 2023
# 1  Black excellence in tech: Panelist Spotlight -...   Feb 13, 2023
# 2  Black excellence in tech: Panelist Spotlight -...   Feb 10, 2023
# 3  Black excellence in tech: Panelist Spotlight -...    Feb 6, 2023
# 4  Coding Bootcamp or Self-Learning? Which is Bes...   Jan 20, 2023
# 5  Codeup Among Top 58 Best Coding Bootcamps of 2...   Jan 12, 2023
#
#                                              content  \
# 0   Codeup is hosting a Black Excellence in Tech ...
# 1  Codeup is hosting our second Black Excellence ...
# 2  Codeup is hosting our second Black Excellence ...
# 3  Codeup is hosting our second Black Excellence ...
# 4  If you’re interested in embarking on a career ...
# 5  Codeup was highlighted for being an establishe...
#
#                                                clean  \
# 0   codeup is hosting a black excellence in tech ...
# 1  codeup is hosting our second black excellence ...
# 2  codeup is hosting our second black excellence ...
# 3  codeup is hosting our second black excellence ...
# 4  if youre interested in embarking on a career i...
# 5  codeup was highlighted for being an establishe...
#
#                                              stemmed  \
# 0  codeup is host a black excel in tech panel in ...
# 1  codeup is host our second black excel in tech ...
# 2  codeup is host our second black excel in tech ...
# 3  codeup is host our second black excel in tech ...
# 4  if your interest in embark on a career in tech...
# 5  codeup wa highlight for be an establish school...
#
#                                           lemmatized
# 0  codeup is hosting a black excellence in tech p...
# 1  codeup is hosting our second black excellence ...
# 2  codeup is hosting our second black excellence ...
# 3  codeup is hosting our second black excellence ...
# 4  if youre interested in embarking on a career i...
# 5  codeup wa highlighted for being an established...
